# %%
#Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Importing datasets
train=pd.read_csv("trainloan.csv")
test=pd.read_csv("testloan.csv")

# %%
#To display first five elements
train.head()
# Out:
#     Loan_ID Gender Married  ... Credit_History Property_Area Loan_Status
# 0  LP001002   Male      No  ...            1.0         Urban           Y
# 1  LP001003   Male     Yes  ...            1.0         Rural           N
# 2  LP001005   Male     Yes  ...            1.0         Urban           Y
# 3  LP001006   Male     Yes  ...            1.0         Urban           Y
# 4  LP001008   Male      No  ...            1.0         Urban           Y
#
# [5 rows x 13 columns]

# %%
test.head()
# Out:
#     Loan_ID Gender Married  ... Credit_History Property_Area Loan_Status
# 0  LP001002   Male      No  ...            1.0         Urban           Y
# 1  LP001003   Male     Yes  ...            1.0         Rural           N
# 2  LP001005   Male     Yes  ...            1.0         Urban           Y
# 3  LP001006   Male     Yes  ...            1.0         Urban           Y
# 4  LP001008   Male      No  ...            1.0         Urban           Y
#
# [5 rows x 13 columns]

# %%
train_org=train.copy()
test.org=test.copy()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
#to find out the size of the dataset 
train.shape,test.shape
# Out:
# ((614, 13), (614, 13))

# %%
train.shape[0]/(train.shape[0]+test.shape[0])
test.shape[0]/(train.shape[0]+test.shape[0])
# Out:
# 0.5

# %%
#to combine train and test data
data=pd.concat([train,test])

# %%
data.head()
# Out:
#     Loan_ID Gender Married  ... Credit_History Property_Area Loan_Status
# 0  LP001002   Male      No  ...            1.0         Urban           Y
# 1  LP001003   Male     Yes  ...            1.0         Rural           N
# 2  LP001005   Male     Yes  ...            1.0         Urban           Y
# 3  LP001006   Male     Yes  ...            1.0         Urban           Y
# 4  LP001008   Male      No  ...            1.0         Urban           Y
#
# [5 rows x 13 columns]

# %%
data.shape
# Out:
# (1228, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1228 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            1228 non-null   object
#  1   Gender             1202 non-null   object
#  2   Married            1222 non-null   object
#  3   Dependents         1198 non-null   object
#  4   Education          1228 non-null   object
#  5   Self_Employed      1164 non-null   object
#  6   ApplicantIncome    1228 non-null   int64
#  7   CoapplicantIncome  1228 non-null   float64
#  8   LoanAmount         1184 non-null   float64
#  9   Loan_Amount_Term   1200 non-null   float64
#  10  Credit_History     1128 non-null   float64
#  11  Property_Area      1228 non-null   object
#  12  Loan_Status        1228 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 134.3+ KB

# %%
data.isnull().sum()
# Out:
# Loan_ID                0
# Gender                26
# Married                6
# Dependents            30
# Education              0
# Self_Employed         64
# ApplicantIncome        0
# CoapplicantIncome      0
# LoanAmount            44
# Loan_Amount_Term      28
# Credit_History       100
# Property_Area          0
# Loan_Status            0
# dtype: int64

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False)

# %%
##univeriate Analysis
data['Loan_Status'].value_counts()
# Out:
# Y    844
# N    384
# Name: Loan_Status, dtype: int64

# %%
data['Loan_Status'].value_counts(normalize=True)
# Out:
# Y    0.687296
# N    0.312704
# Name: Loan_Status, dtype: float64

# %%
#Plot to visualize
sns.countplot('Loan_Status',data=data)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
##independent variable
data['Gender'].value_counts(normalize=True)
sns.countplot('Gender',data=data)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot('Married',data=data)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot("Self_Employed",data=data)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data['Self_Employed'].value_counts(normalize=True)
# Out:
# No     0.859107
# Yes    0.140893
# Name: Self_Employed, dtype: float64

# %%
#credit History
sns.countplot("Credit_History",data=data)
data['Credit_History'].value_counts(normalize=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# 1.0    0.842199
# 0.0    0.157801
# Name: Credit_History, dtype: float64

# %%
#education
sns.countplot("Education",data=data)
data['Education'].value_counts(normalize=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Graduate        0.781759
# Not Graduate    0.218241
# Name: Education, dtype: float64

# %%
#dependent variables
sns.countplot("Dependents",data=data)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#property Area
sns.countplot("Property_Area",data=data)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#numerical variables
plt.subplot(121)
sns.distplot(data['ApplicantIncome'])
plt.subplot(122)
data['ApplicantIncome'].plot.box(figsize=(16,5))
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#coapplicant
plt.subplot(121)
sns.distplot(data['CoapplicantIncome'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#loan amount term
train["Loan_Amount_Term"].value_counts()
train["Loan_Amount_Term"].value_counts(normalize=True)
sns.countplot('Loan_Amount_Term',data=data)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Bivariate Analysis
#Gender vs Loan_status
sns.countplot(x='Gender',hue='Loan_Status',data=data)
print(pd.crosstab(data['Married'],data['Loan_Status']))
sns.countplot('Married',hue='Loan_Status',data=data)
# Out:
# Loan_Status    N    Y
# Married
# No           158  268
# Yes          226  570
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(x='Gender',hue='Loan_Status',data=data)
print(pd.crosstab(data['Dependents'],data['Loan_Status']))
sns.countplot('Dependents',hue='Loan_Status',data=data)
# Out:
# Loan_Status    N    Y
# Dependents
# 0            214  476
# 1             72  132
# 2             50  152
# 3+            36   66
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(x='Gender',hue='Loan_Status',data=data)
print(pd.crosstab(data['Education'],data['Loan_Status']))
sns.countplot('Education',hue='Loan_Status',data=data)
# Out:
# Loan_Status     N    Y
# Education
# Graduate      280  680
# Not Graduate  104  164
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(x='Gender',hue='Loan_Status',data=data)
print(pd.crosstab(data['Self_Employed'],data['Loan_Status']))
sns.countplot('Self_Employed',hue='Loan_Status',data=data)
# Out:
# Loan_Status      N    Y
# Self_Employed
# No             314  686
# Yes             52  112
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(x='Gender',hue='Loan_Status',data=data)
print(pd.crosstab(data['Credit_History'],data['Loan_Status']))
sns.countplot('Credit_History',hue='Loan_Status',data=data)
# Out:
# Loan_Status       N    Y
# Credit_History
# 0.0             164   14
# 1.0             194  756
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(x='Gender',hue='Loan_Status',data=data)
print(pd.crosstab(data['Property_Area'],data['Loan_Status']))
sns.countplot('Property_Area',hue='Loan_Status',data=data)
# Out:
# Loan_Status      N    Y
# Property_Area
# Rural          138  220
# Semiurban      108  358
# Urban          138  266
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(x='Gender',hue='Loan_Status',data=data)
print(pd.crosstab(data['Loan_Status'],data['Loan_Status']))
sns.countplot('Loan_Status',hue='Loan_Status',data=data)
# Out:
# Loan_Status    N    Y
# Loan_Status
# N            384    0
# Y              0  844
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Numerical vs Target variable
sns.scatterplot(x='LoanAmount',y='ApplicantIncome',data=data)

# %%
data_original=data.copy()

# %%
#assign flag to Catergorical variables
data_original['Gender'].unique()
data['Gender']=data['Gender'].map({'Male':1,'Female':0})

# %%
data_original['Married'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
data['Married']=data['Married'].map({'Yes':1,"No":0})

# %%
#dependents
data['Dependents']=data['Dependents'].map({"0":0,"1":1,"2":2})

# %%
data['Education']=data['Education'].map({'Graduate':1,'Not Graduate':0})

# %%
data['Self_Employed']=data['Self_Employed'].map({'Yes':1,'No':0})

# %%
data['Property_Area']=data['Property_Area'].map({'rural':1,'Semiurban':2,'Urban':3})

# %%
data['Loan_Status']=data['Loan_Status'].map({'Y':1,'N':0})

# %%
#Correlation matrix
matrix=data.corr()

# %%
ax=plt.subplots(figsize=(9,6))
sns.heatmap(matrix,vmax=1,square=True,cmap='BuPu',annot=True)
print(matrix)
# Out:
#                      Gender   Married  ...  Property_Area  Loan_Status
# Gender             1.000000  0.369612  ...       0.094229     0.019857
# Married            0.369612  1.000000  ...      -0.002031     0.089280
# Dependents         0.154410  0.352210  ...       0.037674     0.036304
# Education         -0.049258 -0.014223  ...      -0.000745     0.085884
# Self_Employed     -0.009829  0.001909  ...      -0.025013    -0.002303
# ApplicantIncome    0.053989  0.051332  ...       0.009098    -0.004710
# CoapplicantIncome  0.083946  0.077770  ...       0.029829    -0.059187
# LoanAmount         0.106947  0.149519  ...      -0.018798    -0.037318
# Loan_Amount_Term  -0.075117 -0.103810  ...      -0.103408    -0.021268
# Credit_History     0.016337  0.004381  ...      -0.044400     0.561678
# Property_Area      0.094229 -0.002031  ...       1.000000    -0.121625
# Loan_Status        0.019857  0.089280  ...      -0.121625     1.000000
#
# [12 rows x 12 columns]

# %%
data['Dependents']=data['Dependents'].fillna('0')

# %%
data['Dependents'].unique()
# Out:
# array([0.0, 1.0, 2.0, '0'], dtype=object)

# %%
data['Dependents']=data['Dependents'].map({'0':0,'1':1,'3+':4})

# %%
data.isnull().sum()
# Out:
# Loan_ID                 0
# Gender                 26
# Married                 6
# Dependents           1096
# Education               0
# Self_Employed          64
# ApplicantIncome         0
# CoapplicantIncome       0
# LoanAmount             44
# Loan_Amount_Term       28
# Credit_History        100
# Property_Area         358
# Loan_Status             0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['Dependents']=le.fit_transform(data['Dependents'])

# %%
data.isnull().sum()
# Out:
# Loan_ID                0
# Gender                26
# Married                6
# Dependents             0
# Education              0
# Self_Employed         64
# ApplicantIncome        0
# CoapplicantIncome      0
# LoanAmount            44
# Loan_Amount_Term      28
# Credit_History       100
# Property_Area        358
# Loan_Status            0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['Self_Employed']=le.fit_transform(data['Self_Employed'])

# %%
data.isnull().sum()
# Out:
# Loan_ID                0
# Gender                26
# Married                6
# Dependents             0
# Education              0
# Self_Employed          0
# ApplicantIncome        0
# CoapplicantIncome      0
# LoanAmount            44
# Loan_Amount_Term      28
# Credit_History       100
# Property_Area        358
# Loan_Status            0
# dtype: int64

# %%
#data.loc[(data['Gender'].isnull()) and (data['Married']=='Yes'),'Gender']=='Male'

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['Gender']=le.fit_transform(data['Gender'])

# %%
data.isnull().sum()
# Out:
# Loan_ID                0
# Gender                 0
# Married                6
# Dependents             0
# Education              0
# Self_Employed          0
# ApplicantIncome        0
# CoapplicantIncome      0
# LoanAmount            44
# Loan_Amount_Term      28
# Credit_History       100
# Property_Area        358
# Loan_Status            0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['Credit_History']=le.fit_transform(data['Credit_History'])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['Married']=le.fit_transform(data['Married'])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['Property_Area']=le.fit_transform(data['Property_Area'])

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           44
# Loan_Amount_Term     28
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['Loan_Amount_Term']=le.fit_transform(data['Loan_Amount_Term'])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['Loan_Status']=le.fit_transform(data['Loan_Status'])

# %% [markdown]
# # outlier treatment

# %%
data_original['LoanAmount'].quantile([0.1,0.2,0.3])
data_original['LoanAmount'].quantile([1.0,0.99,0.98])
# Out:
# 1.00    700.00
# 0.99    496.68
# 0.98    450.96
# Name: LoanAmount, dtype: float64

# %%
data['LoanAmount']=data['LoanAmount'].fillna(data['LoanAmount'].median())

# %%
ax1=plt.subplot(121)
data['LoanAmount'].hist(bins=20,figsize=(12,4))
ax1.set_title('data')
# Out:
# Text(0.5, 1.0, 'data')

# %%
data_original['Totalincome']=data_original['ApplicantIncome']+data_original['CoapplicantIncome']

# %%
sns.distplot(data_original['Totalincome'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data.head()
# Out:
#     Loan_ID  Gender  Married  ...  Credit_History  Property_Area  Loan_Status
# 0  LP001002       1        0  ...               1              1            1
# 1  LP001003       1        1  ...               1             15            0
# 2  LP001005       1        1  ...               1              1            1
# 3  LP001006       1        1  ...               1              1            1
# 4  LP001008       1        0  ...               1              1            1
#
# [5 rows x 13 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1228 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            1228 non-null   object
#  1   Gender             1228 non-null   int64
#  2   Married            1228 non-null   int64
#  3   Dependents         1228 non-null   int64
#  4   Education          1228 non-null   int64
#  5   Self_Employed      1228 non-null   int64
#  6   ApplicantIncome    1228 non-null   int64
#  7   CoapplicantIncome  1228 non-null   float64
#  8   LoanAmount         1228 non-null   float64
#  9   Loan_Amount_Term   1228 non-null   int64
#  10  Credit_History     1228 non-null   int64
#  11  Property_Area      1228 non-null   int64
#  12  Loan_Status        1228 non-null   int64
# dtypes: float64(2), int64(10), object(1)
# memory usage: 174.3+ KB

# %%
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data=data.drop(['Loan_ID'],axis=1)

# %%
x=data.drop(["Loan_Status"],axis=1)
y=data["Loan_Status"]
#df.drop('Loan_ID',axis=1,inplace=True)

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: Loan_Status, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.head()
# Out:
#      Gender  Married  ...  Credit_History  Property_Area
# 359       1        1  ...               1              0
# 303       1        1  ...               1              1
# 578       1        1  ...               1            142
# 426       0        0  ...               1              7
# 58        1        1  ...               1              1
#
# [5 rows x 11 columns]

# %%
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
rc=RandomForestClassifier()
rc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y2_pred=rc.predict(x_test)

# %%
cm=confusion_matrix(y2_pred,y_test)

# %%
cm
# Out:
# array([[ 54,   4],
#        [ 19, 169]])

# %%
accuracy_score(y2_pred,y_test)
# Out:
# 0.9065040650406504

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y3_pred=dt.predict(x_test)

# %%
cm=confusion_matrix(y3_pred,y_test)

# %%
cm
# Out:
# array([[ 60,  24],
#        [ 13, 149]])

# %%
accuracy_score(y3_pred,y_test)
# Out:
# 0.8495934959349594
